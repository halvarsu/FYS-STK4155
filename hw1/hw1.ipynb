# %%
from sys import version
version
# Out:
# '3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56) \n[GCC 7.2.0]'

# %%
# %matplotlib inline

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ### 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# %%
## 1)
N = 100
x = np.random.random(N)
x = np.sort(x)
noise = 2

from tools import func, get_yhat

X = np.array([x**i for i in range(3)]).T

y = func(x) + noise*np.random.uniform(low=-1, high = 1, size=N)
yhat,beta = get_yhat(X,y)

plt.figure(figsize = [16,9])
plt.plot(x,y, 'o', label = 'data')
plt.plot(x,yhat,   label = 'manual, $y={:.2f} + {:.2f}x + {:.2f}x^2$'.format(*beta))

## 2)
from sklearn.linear_model import LinearRegression 
linreg = LinearRegression(fit_intercept=False)
a = linreg.fit(X,y)
beta_sk = a.coef_
print(a.intercept_)
yhat_sk = linreg.predict(X)

plt.plot(x,yhat_sk,   '--',label = 'scikit, $y={:.2f} + {:.2f}x + {:.2f}x^2$'.format(*beta_sk))
plt.legend()
# Out:
# 0.0

# %% [markdown]
# ### 3)

# %%
from tools import squared_error, R2score

# yhat.shape, y.shape
print('manual')
print('MSE : {:.3f}\nR^2 : {:.3f}'.format(squared_error(y,yhat), R2score(y,yhat)))

from sklearn.metrics import mean_squared_error
print('scikit')
print('MSE : {:.3f}\nR^2 : {:.3f}'.format(mean_squared_error(y,yhat),linreg.score(X,y)))
# Out:
# manual
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-57902083c3fe> in <module>()
#       3 # yhat.shape, y.shape
#       4 print('manual')
# ----> 5 print('MSE : {:.3f}\nR^2 : {:.3f}'.format(squared_error(y,yhat), R2score(y,yhat)))
#       6
#       7 from sklearn.metrics import mean_squared_error
#
# ~/uio/fysstk4155_ml/hw1/tools.py in squared_error(y, yhat)
#      10     if n != yhat.size:
#      11         raise ValueError('vectors must be same size')
# ---> 12     return 1/n*np.sum((y-yhat)**2)
#      13
#      14
#
# NameError: name 'np' is not defined

# %%
X.shape
# Out:
# (100, 3)

# %%
# Out:
# 0.674236538716247

# %% [markdown]
# # Exercise 3
